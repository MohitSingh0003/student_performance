# %% [markdown]
# <a href="https://colab.research.google.com/github/MohitSingh0003/student_performance/blob/main/student_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Student_Performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df["Extracurricular Activities"] = df["Extracurricular Activities"].replace({"Yes": 1, "No": 0})
# Out:
# /tmp/ipython-input-2345818977.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Extracurricular Activities"] = df["Extracurricular Activities"].replace({"Yes": 1, "No": 0})

# %%
x = df.drop("Performance Index", axis=1)
y = df["Performance Index"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("Test")
plt.ylabel("Pred")
# Out:
# Text(0, 0.5, 'Pred')

# %%
model.coef_
# Out:
# array([2.85191442, 1.01886667, 0.66530347, 0.47682996, 0.18776637])

# %%
model.intercept_
# Out:
# np.float64(-34.07520822521347)

# %%
model.score(x_train, y_train)
# Out:
# 0.9889033042773491

# %%
model.score(x_test, y_test)
# Out:
# 0.9880686410711422
